# %%
from tensorflow.keras.models import load_model 
import os

# %%
new_model = load_model(os.path.join('models','final_model_2.h5'))

# %%
import numpy as np
import cv2
import tensorflow as tf
from matplotlib import pyplot as plt

# %% [markdown]
# ## test1

# %% [markdown]
# ##### images in BGR format

# %%
img = cv2.imread('0361 (673).jpg')

# %%
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))

# %%
yhat = new_model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 32ms/step
# array([[0.1592216]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Non-Biodegradable')
else:
    print(f'Predicted class is Biodegradable')
# Out:
# Predicted class is Biodegradable

# %% [markdown]
# ## test2

# %%
img = cv2.imread('TRAIN.2_BIODEG_ORI_203.jpg')

# %%
resize = tf.image.resize(img, (256,256))

# %%
plt.imshow(img)
plt.show()

# %%
yhat = new_model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 30ms/step
# array([[0.00237121]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Non-Biodegradable')
else:
    print(f'Predicted class is Biodegradable')
# Out:
# Predicted class is Biodegradable

# %% [markdown]
# ## test3

# %%
img = cv2.imread('0361 (1134).jpg')

# %%
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))

# %%
yhat = new_model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 30ms/step
# array([[0.00339306]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Non-Biodegradable')
else:
    print(f'Predicted class is Biodegradable')
# Out:
# Predicted class is Biodegradable

# %% [markdown]
# ## test4

# %%
img = cv2.imread('TRAIN.2_NBIODEG_CCW_540.jpg')

# %%
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))

# %%
yhat = new_model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array([[0.9969888]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Non-Biodegradable')
else:
    print(f'Predicted class is Biodegradable')
# Out:
# Predicted class is Non-Biodegradable

# %% [markdown]
# ## test5

# %%
img = cv2.imread('000000101 (61).jpg')

# %%
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))

# %%
yhat = new_model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 30ms/step
# array([[0.93891346]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Non-Biodegradable')
else:
    print(f'Predicted class is Biodegradable')
# Out:
# Predicted class is Non-Biodegradable

# %% [markdown]
# ## test6

# %%
img = cv2.imread('crushedcan.jpeg')

# %%
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))

# %%
yhat = new_model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array([[0.9998055]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Non-Biodegradable')
else:
    print(f'Predicted class is Biodegradable')
# Out:
# Predicted class is Non-Biodegradable
